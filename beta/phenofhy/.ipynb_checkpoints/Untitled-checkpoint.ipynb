# %%
# !ls
# Out:
# Untitled.ipynb	  _filter_funcs.py  display.py	load.py      profile.py
# __init__.py	  _rules.py	    extract.py	pipeline.py  simulate.py
# _derive_funcs.py  calculate.py	    icd.py	process.py   utils.py

# %%
import simulate

# %%
simulate.simulate_phenotype_df(sample=1000, fields=None, *,
	include_nonresponse=False, missing_rate=None, seed=None)
# Out:
#   Cell In[28], line 1
#     simulate.simulate_phenotype_df(sample=1000, fields=None, *,
#                                                               ^
# SyntaxError: iterable argument unpacking follows keyword argument unpacking
